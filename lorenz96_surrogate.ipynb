# %% [markdown]
# Open this notebook in Google Colab by clicking the link below:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gurol/lorenz96_ml/blob/main/lorenz96_surrogate.ipynb)

# %% [markdown]
# # Practical: Using neural networks to learn surrogate models for chaotic systems
# Author: Rachid El Montassir
#
#
# - This notebook is inspired by the lecture notes of the course ["Introduction to the principles and methods of data assimilation in the geosciences"](https://cerea.enpc.fr/HomePages/bocquet/teaching/assim-mb-en-0.52.pdf) by M. Bocquet and A. Farchi.
#
# The aim of this lab is to introduce and compare different neural network architectures for modelling the dynamics of a chaotic system — the **Lorenz-96 model** — with a focus on **embedding physical structure into neural networks**. Through this exercise, you will learn how simple architectural choices (e.g. convolutions or integration schemes) can dramatically affect the predictive skill of a learned model.

# %% [markdown]
# ## The Lorenz-96 System
#
# We consider the classical Lorenz-96 system of dimension $N_x$, governed by:
#
# $$
# \frac{dx_i}{dt} = (x_{i+1} - x_{i-2})x_{i-1} - x_i + F
# $$
#
# where $F$ is a forcing parameter (typically $F = 8$), and indices are interpreted modulo $N_x$ (periodic boundary conditions). The system exhibits chaotic behaviour and serves as a toy model for high-dimensional, non-linear geophysical dynamics.

# %%
! git clone https://github.com/sgurol/lorenz96_ml.git
! pip install cmocean
# Out:
# Cloning into 'lorenz96'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 46 (delta 15), reused 40 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 10.14 MiB | 25.90 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# Collecting cmocean
#   Downloading cmocean-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from cmocean) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from cmocean) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from cmocean) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->cmocean) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->cmocean) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->cmocean) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->cmocean) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->cmocean) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->cmocean) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->cmocean) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->cmocean) (1.17.0)
# Downloading cmocean-4.0.3-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: cmocean
# Successfully installed cmocean-4.0.3

# %%
import torch.nn.functional as F
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader
import cmocean
import os
from lorenz96.lorenz96_utils import Lorenz96, plot_lorenz96_trajectory, preprocess_dataset
from lorenz96.lorenz96_utils import PATH

# %% [markdown]
# ## Models

# %% [markdown]
# ### 1. Simple feedforward neural network
# A simple feedforward neural network that takes the state $x_t$ as input and outputs the state $x_{t+1}$ at the next time step. The model is trained to minimize the mean squared error between the predicted and true states.

# %%
class NaiveNetwork(nn.Module):
    def __init__(self, Nx, num_layers=4):
        super(NaiveNetwork, self).__init__()
        self.Nx = Nx
        self.sequential = nn.Sequential(
            nn.Linear(Nx, 128),
            nn.ReLU(),
            *[
                nn.Sequential(
                    nn.Linear(128, 128),
                    nn.ReLU()
                ) for _ in range(num_layers - 2)
            ])
        self.linear = nn.Linear(128, Nx)

    def forward(self, x):
        x = self.sequential(x)
        x = self.linear(x)
        return x

    def predict(self, x, steps=1):
        for _ in range(steps):
            x = self.forward(x)
        return x

# %% [markdown]
# ### Training
# The model is trained using the Adam optimizer with a starting learning rate of $10^{-3}$ and a batch size of 64. The training is performed for 100 epochs, and the model is evaluated on a validation set after each epoch. The best model is saved based on the validation loss.

# %%
class Trainer:
    def __init__(self, model, train_loader, val_loader, mean, std, device='cuda',
                 model_type='hybrid', patience=15, dt=0.01, F=8.0):
        self.dt = dt
        self.F = F
        self.Nx = model.Nx
        self.model_type = model_type
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.mean = mean
        self.std = std
        self.device = device
        self.patience = patience
        self.model.to(self.device)

    def train(self, epochs=20, lr=1e-3):
        print(f"Training on device: {self.device}")
        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        criterion = nn.MSELoss()
        sstep = epochs // 6
        scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer, step_size=sstep, gamma=0.5)  # Reduce LR every 10 epochs
        losses = {'train': [], 'val': []}

        best_val_loss = float('inf')
        patience_counter = 0

        for epoch in range(epochs):
            self.model.train()
            train_loss = 0.0
            for x, y in self.train_loader:
                x, y = x.to(self.device), y.to(self.device)
                pred = self.model(x)
                loss = criterion(pred - x, y - x)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                train_loss += loss.item()
            scheduler.step()
            losses['train'].append(train_loss / len(self.train_loader))

            self.model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for x, y in self.val_loader:
                    x, y = x.to(self.device), y.to(self.device)
                    pred = self.model(x)
                    loss = criterion(pred - x, y - x)
                    val_loss += loss.item()
            val_loss /= len(self.val_loader)
            losses['val'].append(val_loss)

            print(f"[Epoch {epoch+1}] Train loss: {train_loss/len(self.train_loader):.4e} | "
                  f"Val loss: {val_loss:.4e}")

            # Early stopping
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                patience_counter = 0
                torch.save(self.model.state_dict(), os.path.join(PATH,
                           f'{self.model_type}/best_dt{self.dt}_Nx{self.Nx}_F{self.F}_network.pth'))
                # print(
                #     f"Best model saved as {self.model_type}/best_dt{self.dt}_Nx{self.Nx}_F{self.F}_network.pth")
            else:
                patience_counter += 1
                if patience_counter >= self.patience:
                    print("Early stopping triggered.")
                    break

        self._plot_losses(losses)
        print(f"Final model saved as {self.model_type}/dt{self.dt}_Nx{self.Nx}_F{self.F}_network.pth")
        torch.save(self.model.state_dict(), os.path.join(PATH,
                   f'{self.model_type}/dt{self.dt}_Nx{self.Nx}_F{self.F}_network.pth'))

    def _plot_losses(self, losses):
        plt.figure(figsize=(10, 5))
        plt.plot(losses['train'], label='Train loss')
        plt.plot(losses['val'], label='Validation loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'{PATH}/{self.model_type}/training_loss.png', dpi=300)
        plt.show()

# %% [markdown]
# ### Inference

# %%
class Inference:
    def __init__(self, model, mean, std, device='cuda', model_type='hybrid'):
        self.model_type = model_type
        self.model = model
        self.mean = mean
        self.std = std
        self.device = device
        self.model.to(self.device)
        self.model.eval()

    @torch.no_grad()
    def predict_trajectory(self, data_set, steps=40, Nx=40):
        x_val = data_set[0][0]  # Get the first sample
        x_val = x_val.unsqueeze(0).to(self.device)  # Add batch dimension
        predicted_trajectory = np.zeros((steps, Nx))

        for t in range(steps):
            x_val = self.model.predict(x_val, steps=1)
            x_val_out = x_val.cpu().numpy() * self.std + self.mean  # Denormalise
            predicted_trajectory[t] = x_val_out

        self._plot_trajectory(predicted_trajectory,
                              title=f'{self.model_type.capitalize()} model predicted', vmin=-10, vmax=15)
        # plot validation trajectory
        val_trajectory = np.zeros((steps, Nx))
        for t in range(steps):
            x_val = data_set[t+1][0]
            val_trajectory[t] = x_val.numpy() * self.std + self.mean
        self._plot_trajectory(val_trajectory, title='True', vmin=-10, vmax=15)
        # plot the error
        error = predicted_trajectory - val_trajectory
        self._plot_trajectory(error, title=f'{self.model_type.capitalize()} model error',
                              vmin=-15, vmax=15)

    def _plot_trajectory(self, trajectory, title='Predicted', vmin=None, vmax=None):
        if vmin is not None and vmin == -vmax:
            cmap = cmocean.cm.balance
        else:
            cmap = cmocean.cm.curl
        plt.figure(figsize=(10, 5))
        plt.imshow(trajectory.T, aspect='auto', cmap=cmap,
                   origin='lower', interpolation='spline36', vmin=vmin, vmax=vmax)
        cbar_label = 'Error value' if 'Error' in title else 'State value'
        plt.colorbar(label=cbar_label)
        plt.xlabel('Time step')
        plt.ylabel('Lorenz96 variables')
        plt.title(f'{title} Lorenz-96 trajectory')
        plt.tight_layout()
        plt.savefig(
            f'{PATH}/{title.replace(" ", "_").lower()}_traj.png', dpi=300)
        plt.show()

# %%
Nt_train = 10000
Nx = 40
dt = 0.01
F = 8.0
# Use double precision, simple precision could also be used
torch.set_default_dtype(torch.float64)
true_model = Lorenz96(Nx=Nx, dt=dt, F=F, integrator='rk4')
xt = true_model.generate_dataset(
    Nt_train=Nt_train, Nt_spinup=1000, seed=42, Nt_shift=10)
# change xt to double precision
xt = xt.astype(np.float64)

# Plot heatmap of trajectory
plot_lorenz96_trajectory(xt, Nt=50, mode='heatmap')
# Out:
# Dataset loaded from lorenz96/outputs/lorenz96_dataset_Nt10000_Nx40_F8.0.npz

# %%
train_set, val_set, mean, std = preprocess_dataset(xt)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64)

# %%
model_type="naive"
# Initialize model
model = NaiveNetwork(Nx=true_model.Nx)

# %%
epochs = 100
# Train the model
trainer = Trainer(model, train_loader, val_loader, mean, std,
                    device='cuda' if torch.cuda.is_available() else 'cpu',
                    model_type=model_type, dt=dt, F=F)
trainer.train(epochs=epochs, lr=1e-3)
# Out:
# Training on device: cpu
# [Epoch 1] Train loss: 5.5807e-01 | Val loss: 3.2538e-01
# [Epoch 2] Train loss: 2.6482e-01 | Val loss: 2.3033e-01
# [Epoch 3] Train loss: 2.0205e-01 | Val loss: 1.9136e-01
# [Epoch 4] Train loss: 1.7230e-01 | Val loss: 1.7128e-01
# [Epoch 5] Train loss: 1.5548e-01 | Val loss: 1.6117e-01
# [Epoch 6] Train loss: 1.4379e-01 | Val loss: 1.4982e-01
# [Epoch 7] Train loss: 1.3320e-01 | Val loss: 1.3877e-01
# [Epoch 8] Train loss: 1.2358e-01 | Val loss: 1.3149e-01
# [Epoch 9] Train loss: 1.1415e-01 | Val loss: 1.2466e-01
# [Epoch 10] Train loss: 1.0623e-01 | Val loss: 1.1771e-01
# [Epoch 11] Train loss: 9.8875e-02 | Val loss: 1.0717e-01
# [Epoch 12] Train loss: 9.2041e-02 | Val loss: 1.0136e-01
# [Epoch 13] Train loss: 8.5845e-02 | Val loss: 9.3430e-02
# [Epoch 14] Train loss: 8.0438e-02 | Val loss: 8.9340e-02
# [Epoch 15] Train loss: 7.5542e-02 | Val loss: 8.3906e-02
# [Epoch 16] Train loss: 7.1115e-02 | Val loss: 7.8718e-02
# [Epoch 17] Train loss: 6.4449e-02 | Val loss: 7.3241e-02
# [Epoch 18] Train loss: 6.2707e-02 | Val loss: 7.1370e-02
# [Epoch 19] Train loss: 6.1130e-02 | Val loss: 6.8638e-02
# [Epoch 20] Train loss: 5.9574e-02 | Val loss: 6.7576e-02
# [Epoch 21] Train loss: 5.8039e-02 | Val loss: 6.5033e-02
# [Epoch 22] Train loss: 5.6756e-02 | Val loss: 6.4623e-02
# [Epoch 23] Train loss: 5.5362e-02 | Val loss: 6.2542e-02
# [Epoch 24] Train loss: 5.4215e-02 | Val loss: 6.0484e-02
# [Epoch 25] Train loss: 5.3158e-02 | Val loss: 5.8970e-02
# [Epoch 26] Train loss: 5.1965e-02 | Val loss: 5.9078e-02
# [Epoch 27] Train loss: 5.1088e-02 | Val loss: 5.7358e-02
# [Epoch 28] Train loss: 4.9976e-02 | Val loss: 5.6253e-02
# [Epoch 29] Train loss: 4.8982e-02 | Val loss: 5.5659e-02
# [Epoch 30] Train loss: 4.8018e-02 | Val loss: 5.4792e-02
# [Epoch 31] Train loss: 4.7302e-02 | Val loss: 5.2594e-02
# [Epoch 32] Train loss: 4.6315e-02 | Val loss: 5.2251e-02
# [Epoch 33] Train loss: 4.4125e-02 | Val loss: 5.0456e-02
# [Epoch 34] Train loss: 4.3707e-02 | Val loss: 4.9709e-02
# [Epoch 35] Train loss: 4.3344e-02 | Val loss: 4.9258e-02
# [Epoch 36] Train loss: 4.2947e-02 | Val loss: 4.9253e-02
# [Epoch 37] Train loss: 4.2641e-02 | Val loss: 4.8687e-02
# [Epoch 38] Train loss: 4.2171e-02 | Val loss: 4.7975e-02
# [Epoch 39] Train loss: 4.1958e-02 | Val loss: 4.7826e-02
# [Epoch 40] Train loss: 4.1669e-02 | Val loss: 4.7629e-02
# [Epoch 41] Train loss: 4.1321e-02 | Val loss: 4.7536e-02
# [Epoch 42] Train loss: 4.1045e-02 | Val loss: 4.6549e-02
# [Epoch 43] Train loss: 4.0782e-02 | Val loss: 4.6539e-02
# [Epoch 44] Train loss: 4.0356e-02 | Val loss: 4.6217e-02
# [Epoch 45] Train loss: 4.0235e-02 | Val loss: 4.5568e-02
# [Epoch 46] Train loss: 3.9959e-02 | Val loss: 4.5639e-02
# [Epoch 47] Train loss: 3.9631e-02 | Val loss: 4.4971e-02
# [Epoch 48] Train loss: 3.9430e-02 | Val loss: 4.5270e-02
# [Epoch 49] Train loss: 3.8373e-02 | Val loss: 4.3764e-02
# [Epoch 50] Train loss: 3.8143e-02 | Val loss: 4.3674e-02
# [Epoch 51] Train loss: 3.8052e-02 | Val loss: 4.3627e-02
# [Epoch 52] Train loss: 3.7893e-02 | Val loss: 4.3513e-02
# [Epoch 53] Train loss: 3.7771e-02 | Val loss: 4.3666e-02
# [Epoch 54] Train loss: 3.7691e-02 | Val loss: 4.3278e-02
# [Epoch 55] Train loss: 3.7616e-02 | Val loss: 4.3298e-02
# [Epoch 56] Train loss: 3.7446e-02 | Val loss: 4.2854e-02
# [Epoch 57] Train loss: 3.7356e-02 | Val loss: 4.2966e-02
# [Epoch 58] Train loss: 3.7216e-02 | Val loss: 4.2492e-02
# [Epoch 59] Train loss: 3.7107e-02 | Val loss: 4.2346e-02
# [Epoch 60] Train loss: 3.6961e-02 | Val loss: 4.2293e-02
# [Epoch 61] Train loss: 3.6853e-02 | Val loss: 4.2366e-02
# [Epoch 62] Train loss: 3.6809e-02 | Val loss: 4.2128e-02
# [Epoch 63] Train loss: 3.6596e-02 | Val loss: 4.1884e-02
# [Epoch 64] Train loss: 3.6519e-02 | Val loss: 4.1794e-02
# [Epoch 65] Train loss: 3.5968e-02 | Val loss: 4.1496e-02
# [Epoch 66] Train loss: 3.5875e-02 | Val loss: 4.1313e-02
# [Epoch 67] Train loss: 3.5837e-02 | Val loss: 4.1123e-02
# [Epoch 68] Train loss: 3.5803e-02 | Val loss: 4.1218e-02
# [Epoch 69] Train loss: 3.5720e-02 | Val loss: 4.1067e-02
# [Epoch 70] Train loss: 3.5666e-02 | Val loss: 4.0968e-02
# [Epoch 71] Train loss: 3.5610e-02 | Val loss: 4.0898e-02
# [Epoch 72] Train loss: 3.5566e-02 | Val loss: 4.1062e-02
# [Epoch 73] Train loss: 3.5530e-02 | Val loss: 4.0839e-02
# [Epoch 74] Train loss: 3.5455e-02 | Val loss: 4.0714e-02
# [Epoch 75] Train loss: 3.5404e-02 | Val loss: 4.0866e-02
# [Epoch 76] Train loss: 3.5342e-02 | Val loss: 4.0732e-02
# [Epoch 77] Train loss: 3.5277e-02 | Val loss: 4.0599e-02
# [Epoch 78] Train loss: 3.5233e-02 | Val loss: 4.0527e-02
# [Epoch 79] Train loss: 3.5190e-02 | Val loss: 4.0384e-02
# [Epoch 80] Train loss: 3.5109e-02 | Val loss: 4.0271e-02
# [Epoch 81] Train loss: 3.4817e-02 | Val loss: 4.0160e-02
# [Epoch 82] Train loss: 3.4780e-02 | Val loss: 4.0149e-02
# [Epoch 83] Train loss: 3.4744e-02 | Val loss: 4.0136e-02
# [Epoch 84] Train loss: 3.4716e-02 | Val loss: 4.0078e-02
# [Epoch 85] Train loss: 3.4676e-02 | Val loss: 4.0037e-02
# [Epoch 86] Train loss: 3.4685e-02 | Val loss: 3.9948e-02
# [Epoch 87] Train loss: 3.4631e-02 | Val loss: 4.0113e-02
# [Epoch 88] Train loss: 3.4626e-02 | Val loss: 3.9862e-02
# [Epoch 89] Train loss: 3.4595e-02 | Val loss: 3.9968e-02
# [Epoch 90] Train loss: 3.4574e-02 | Val loss: 3.9941e-02
# [Epoch 91] Train loss: 3.4540e-02 | Val loss: 3.9895e-02
# [Epoch 92] Train loss: 3.4500e-02 | Val loss: 3.9827e-02
# [Epoch 93] Train loss: 3.4472e-02 | Val loss: 3.9829e-02
# [Epoch 94] Train loss: 3.4448e-02 | Val loss: 3.9779e-02
# [Epoch 95] Train loss: 3.4438e-02 | Val loss: 3.9731e-02
# [Epoch 96] Train loss: 3.4384e-02 | Val loss: 3.9697e-02
# [Epoch 97] Train loss: 3.4216e-02 | Val loss: 3.9556e-02
# [Epoch 98] Train loss: 3.4196e-02 | Val loss: 3.9551e-02
# [Epoch 99] Train loss: 3.4203e-02 | Val loss: 3.9507e-02
# [Epoch 100] Train loss: 3.4178e-02 | Val loss: 3.9513e-02
# Final model saved as lorenz96/outputsnaive_network.pth

# %%
Nt = 25

# Load the model, uncomment to load stored weights
# model.load_state_dict(torch.load(
#    f'{PATH}/stored/{model_type}/best_dt{dt}_Nx{Nx}_F{F}_network.pth', weights_only=True))

# Predictions
inference = Inference(model, mean, std, model_type=model_type,
                        device='cuda' if torch.cuda.is_available() else 'cpu')
inference.predict_trajectory(val_set, steps=Nt, Nx=true_model.Nx)

# %% [markdown]
# ### 2. Convolutional neural network (CNN)
# A convolutional neural network that takes the state $x_t$ as input and outputs the state $x_{t+1}$ at the next time step.

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self, Nx, num_filters=64, kernel_size=5):
        super(ConvolutionalNetwork, self).__init__()
        self.Nx = Nx

        # Convolutional layers
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=num_filters,
                               kernel_size=kernel_size, padding=kernel_size//2)
        self.conv4 = nn.Conv1d(in_channels=num_filters, out_channels=1,
                               kernel_size=kernel_size, padding=kernel_size//2)

        # Activation function
        self.relu = nn.ReLU()

    def forward(self, x):
        # Add channel dimension and apply convolutions
        x = x.unsqueeze(1)  # (B, 1, Nx) -- Add channel dimension
        x = self.relu(self.conv1(x))  # Apply Conv1
        x = self.conv4(x)  # Apply Conv4 to reduce to 1 channel
        return x.squeeze(1)  # Remove channel dimension and return (B, Nx)

    def predict(self, x, steps=1):
        """
        Predict the next state using the model for a given number of steps.
        """
        for _ in range(steps):
            x = self.forward(x)
        return x

# %%
model_type = 'conv'
model = ConvolutionalNetwork(
    Nx=true_model.Nx, num_filters=64, kernel_size=5)

# %%
epochs = 100
# Train the model
trainer = Trainer(model, train_loader, val_loader, mean, std,
                    device='cuda' if torch.cuda.is_available() else 'cpu',
                    model_type=model_type, dt=dt, F=F)
trainer.train(epochs=epochs, lr=1e-3)
# Out:
# Training on device: cpu
# [Epoch 1] Train loss: 1.4210e-01 | Val loss: 4.2788e-02
# [Epoch 2] Train loss: 3.5141e-02 | Val loss: 3.1031e-02
# [Epoch 3] Train loss: 2.6795e-02 | Val loss: 2.4711e-02
# [Epoch 4] Train loss: 2.1599e-02 | Val loss: 2.0917e-02
# [Epoch 5] Train loss: 1.8633e-02 | Val loss: 1.8797e-02
# [Epoch 6] Train loss: 1.6902e-02 | Val loss: 1.7442e-02
# [Epoch 7] Train loss: 1.5743e-02 | Val loss: 1.6498e-02
# [Epoch 8] Train loss: 1.4908e-02 | Val loss: 1.5776e-02
# [Epoch 9] Train loss: 1.4238e-02 | Val loss: 1.5208e-02
# [Epoch 10] Train loss: 1.3748e-02 | Val loss: 1.4757e-02
# [Epoch 11] Train loss: 1.3327e-02 | Val loss: 1.4407e-02
# [Epoch 12] Train loss: 1.2989e-02 | Val loss: 1.4122e-02
# [Epoch 13] Train loss: 1.2719e-02 | Val loss: 1.3897e-02
# [Epoch 14] Train loss: 1.2490e-02 | Val loss: 1.3641e-02
# [Epoch 15] Train loss: 1.2262e-02 | Val loss: 1.3447e-02
# [Epoch 16] Train loss: 1.2094e-02 | Val loss: 1.3314e-02
# [Epoch 17] Train loss: 1.1932e-02 | Val loss: 1.3178e-02
# [Epoch 18] Train loss: 1.1849e-02 | Val loss: 1.3098e-02
# [Epoch 19] Train loss: 1.1782e-02 | Val loss: 1.3021e-02
# [Epoch 20] Train loss: 1.1726e-02 | Val loss: 1.2970e-02
# [Epoch 21] Train loss: 1.1645e-02 | Val loss: 1.2888e-02
# [Epoch 22] Train loss: 1.1602e-02 | Val loss: 1.2856e-02
# [Epoch 23] Train loss: 1.1529e-02 | Val loss: 1.2833e-02
# [Epoch 24] Train loss: 1.1489e-02 | Val loss: 1.2766e-02
# [Epoch 25] Train loss: 1.1429e-02 | Val loss: 1.2682e-02
# [Epoch 26] Train loss: 1.1387e-02 | Val loss: 1.2627e-02
# [Epoch 27] Train loss: 1.1346e-02 | Val loss: 1.2586e-02
# [Epoch 28] Train loss: 1.1319e-02 | Val loss: 1.2546e-02
# [Epoch 29] Train loss: 1.1265e-02 | Val loss: 1.2540e-02
# [Epoch 30] Train loss: 1.1219e-02 | Val loss: 1.2489e-02
# [Epoch 31] Train loss: 1.1207e-02 | Val loss: 1.2453e-02
# [Epoch 32] Train loss: 1.1163e-02 | Val loss: 1.2507e-02
# [Epoch 33] Train loss: 1.1116e-02 | Val loss: 1.2392e-02
# [Epoch 34] Train loss: 1.1089e-02 | Val loss: 1.2371e-02
# [Epoch 35] Train loss: 1.1074e-02 | Val loss: 1.2360e-02
# [Epoch 36] Train loss: 1.1060e-02 | Val loss: 1.2352e-02
# [Epoch 37] Train loss: 1.1047e-02 | Val loss: 1.2328e-02
# [Epoch 38] Train loss: 1.1047e-02 | Val loss: 1.2307e-02
# [Epoch 39] Train loss: 1.1012e-02 | Val loss: 1.2297e-02
# [Epoch 40] Train loss: 1.0995e-02 | Val loss: 1.2284e-02
# [Epoch 41] Train loss: 1.0976e-02 | Val loss: 1.2297e-02
# [Epoch 42] Train loss: 1.0972e-02 | Val loss: 1.2251e-02
# [Epoch 43] Train loss: 1.0951e-02 | Val loss: 1.2234e-02
# [Epoch 44] Train loss: 1.0947e-02 | Val loss: 1.2226e-02
# [Epoch 45] Train loss: 1.0921e-02 | Val loss: 1.2205e-02
# [Epoch 46] Train loss: 1.0902e-02 | Val loss: 1.2180e-02
# [Epoch 47] Train loss: 1.0884e-02 | Val loss: 1.2192e-02
# [Epoch 48] Train loss: 1.0883e-02 | Val loss: 1.2163e-02
# [Epoch 49] Train loss: 1.0844e-02 | Val loss: 1.2150e-02
# [Epoch 50] Train loss: 1.0846e-02 | Val loss: 1.2140e-02
# [Epoch 51] Train loss: 1.0821e-02 | Val loss: 1.2121e-02
# [Epoch 52] Train loss: 1.0820e-02 | Val loss: 1.2124e-02
# [Epoch 53] Train loss: 1.0808e-02 | Val loss: 1.2104e-02
# [Epoch 54] Train loss: 1.0799e-02 | Val loss: 1.2116e-02
# [Epoch 55] Train loss: 1.0789e-02 | Val loss: 1.2112e-02
# [Epoch 56] Train loss: 1.0789e-02 | Val loss: 1.2101e-02
# [Epoch 57] Train loss: 1.0777e-02 | Val loss: 1.2090e-02
# [Epoch 58] Train loss: 1.0787e-02 | Val loss: 1.2070e-02
# [Epoch 59] Train loss: 1.0770e-02 | Val loss: 1.2058e-02
# [Epoch 60] Train loss: 1.0746e-02 | Val loss: 1.2064e-02
# [Epoch 61] Train loss: 1.0731e-02 | Val loss: 1.2040e-02
# [Epoch 62] Train loss: 1.0733e-02 | Val loss: 1.2029e-02
# [Epoch 63] Train loss: 1.0730e-02 | Val loss: 1.2023e-02
# [Epoch 64] Train loss: 1.0719e-02 | Val loss: 1.2020e-02
# [Epoch 65] Train loss: 1.0706e-02 | Val loss: 1.2004e-02
# [Epoch 66] Train loss: 1.0702e-02 | Val loss: 1.2001e-02
# [Epoch 67] Train loss: 1.0699e-02 | Val loss: 1.2001e-02
# [Epoch 68] Train loss: 1.0692e-02 | Val loss: 1.1990e-02
# [Epoch 69] Train loss: 1.0678e-02 | Val loss: 1.1992e-02
# [Epoch 70] Train loss: 1.0681e-02 | Val loss: 1.1981e-02
# [Epoch 71] Train loss: 1.0681e-02 | Val loss: 1.1976e-02
# [Epoch 72] Train loss: 1.0668e-02 | Val loss: 1.1979e-02
# [Epoch 73] Train loss: 1.0662e-02 | Val loss: 1.1969e-02
# [Epoch 74] Train loss: 1.0671e-02 | Val loss: 1.1972e-02
# [Epoch 75] Train loss: 1.0661e-02 | Val loss: 1.1961e-02
# [Epoch 76] Train loss: 1.0662e-02 | Val loss: 1.1958e-02
# [Epoch 77] Train loss: 1.0647e-02 | Val loss: 1.1956e-02
# [Epoch 78] Train loss: 1.0646e-02 | Val loss: 1.1951e-02
# [Epoch 79] Train loss: 1.0643e-02 | Val loss: 1.1958e-02
# [Epoch 80] Train loss: 1.0642e-02 | Val loss: 1.1938e-02
# [Epoch 81] Train loss: 1.0628e-02 | Val loss: 1.1936e-02
# [Epoch 82] Train loss: 1.0630e-02 | Val loss: 1.1934e-02
# [Epoch 83] Train loss: 1.0623e-02 | Val loss: 1.1938e-02
# [Epoch 84] Train loss: 1.0622e-02 | Val loss: 1.1932e-02
# [Epoch 85] Train loss: 1.0613e-02 | Val loss: 1.1927e-02
# [Epoch 86] Train loss: 1.0624e-02 | Val loss: 1.1926e-02
# [Epoch 87] Train loss: 1.0624e-02 | Val loss: 1.1928e-02
# [Epoch 88] Train loss: 1.0612e-02 | Val loss: 1.1923e-02
# [Epoch 89] Train loss: 1.0616e-02 | Val loss: 1.1921e-02
# [Epoch 90] Train loss: 1.0607e-02 | Val loss: 1.1922e-02
# [Epoch 91] Train loss: 1.0614e-02 | Val loss: 1.1915e-02
# [Epoch 92] Train loss: 1.0601e-02 | Val loss: 1.1918e-02
# [Epoch 93] Train loss: 1.0601e-02 | Val loss: 1.1913e-02
# [Epoch 94] Train loss: 1.0606e-02 | Val loss: 1.1912e-02
# [Epoch 95] Train loss: 1.0596e-02 | Val loss: 1.1911e-02
# [Epoch 96] Train loss: 1.0595e-02 | Val loss: 1.1908e-02
# [Epoch 97] Train loss: 1.0597e-02 | Val loss: 1.1903e-02
# [Epoch 98] Train loss: 1.0581e-02 | Val loss: 1.1903e-02
# [Epoch 99] Train loss: 1.0598e-02 | Val loss: 1.1904e-02
# [Epoch 100] Train loss: 1.0608e-02 | Val loss: 1.1900e-02
# Final model saved as lorenz96/outputsconv_network.pth

# %%
Nt = 25

# Load the model, uncomment to load stored weights
# model.load_state_dict(torch.load(
#    f'{PATH}/stored/{model_type}/best_dt{dt}_Nx{Nx}_F{F}_network.pth', weights_only=True))

# Predictions
inference = Inference(model, mean, std, model_type=model_type,
                        device='cuda' if torch.cuda.is_available() else 'cpu')
inference.predict_trajectory(val_set, steps=Nt, Nx=true_model.Nx)

# %% [markdown]
# ### 3. Hybrid model
# A hybrid model that combines: a CNN-based architecture for computing the tendency $\frac{dx}{dt}$, an explicit integration scheme (Euler, RK2, RK4), and periodic padding to enforce spatial boundary conditions.
#
# - The **tendency** term approximate a learnable physical tendency function, inspired by differential equations with nonlinear terms. This means that we don't need to hard-code the theoretical tendency. Instead, we can learn it from the data.

# %%
class HybridNetwork(nn.Module):
    def __init__(self, Nx, num_filters=6, kernel_size=5, dt=0.01, integrator='euler'):
        super(HybridNetwork, self).__init__()
        self.Nx = Nx
        self.dt = dt
        self.border = kernel_size // 2
        self.integrator = integrator

        # Convolutional layers
        self.conv1 = nn.Conv1d(
            in_channels=1, out_channels=num_filters, kernel_size=kernel_size)
        self.conv2 = nn.Conv1d(in_channels=num_filters * 2,
                               out_channels=1, kernel_size=1)

    def pad(self, x):
        # Periodic padding
        left = x[..., -self.border:]
        right = x[..., :self.border]
        return torch.cat([left, x, right], dim=-1)

    def tendency(self, x):
        x = x.unsqueeze(1)  # (B, 1, Nx)
        x_pad = self.pad(x)  # Periodic padding

        x1 = self.conv1(x_pad)  # (B, F, Nx)
        x2 = x1 ** 2            # Quadratic nonlinearity

        x_cat = torch.cat([x1, x2], dim=1)  # (B, 2F, Nx)
        out = self.conv2(x_cat)             # (B, 1, Nx)

        return out.squeeze(1)               # (B, Nx)

    def forward(self, x):
        if self.integrator == 'euler':
            return self.euler_step(x)
        elif self.integrator == 'rk2':
            return self.rk2_step(x)
        elif self.integrator == 'rk4':
            return self.rk4_step(x)
        else:
            raise ValueError(
                "Invalid integrator. Use 'euler', 'rk2', or 'rk4'.")

    def euler_step(self, x):
        """
        Euler integration step.
        """
        dx = self.tendency(x)
        return x + self.dt * dx

    def rk2_step(self, x):
        """
        Runge-Kutta 2nd order integration
        """
        k1 = self.tendency(x)
        k2 = self.tendency(x + self.dt * k1)
        dx = (k1 + k2) / 2
        return x + self.dt * dx

    def rk4_step(self, x):
        """
        Runge-Kutta 4th order integration
        """
        k1 = self.tendency(x)
        k2 = self.tendency(x + 0.5 * self.dt * k1)
        k3 = self.tendency(x + 0.5 * self.dt * k2)
        k4 = self.tendency(x + self.dt * k3)
        dx = (k1 + 2 * k2 + 2 * k3 + k4) / 6
        return x + self.dt * dx

    def predict(self, x, steps=1):
        """
        Predict the next state using the model for a given number of steps.
        """
        for _ in range(steps):
            x = self.forward(x)
        return x

# %%
model_type="hybrid"
# hybrid network
# Use the same parameters as the true model
# Nx = true_model.Nx, dt = true_model.dt, integrator = true_model.integrator
model = HybridNetwork(Nx=Nx, num_filters=6,
                        kernel_size=5, dt=dt, integrator='rk4')

# %%
epochs = 100
# Train the model
trainer = Trainer(model, train_loader, val_loader, mean, std,
                    device='cuda' if torch.cuda.is_available() else 'cpu',
                    model_type=model_type, dt=dt, F=F)
trainer.train(epochs=epochs, lr=1e-3)
# Out:
# Training on device: cpu
# [Epoch 1] Train loss: 2.4332e-01 | Val loss: 2.3028e-01
# [Epoch 2] Train loss: 2.2401e-01 | Val loss: 1.9923e-01
# [Epoch 3] Train loss: 1.8292e-01 | Val loss: 1.5612e-01
# [Epoch 4] Train loss: 1.4176e-01 | Val loss: 1.2207e-01
# [Epoch 5] Train loss: 1.1217e-01 | Val loss: 9.8926e-02
# [Epoch 6] Train loss: 9.1218e-02 | Val loss: 8.0431e-02
# [Epoch 7] Train loss: 7.2165e-02 | Val loss: 6.0719e-02
# [Epoch 8] Train loss: 5.2188e-02 | Val loss: 4.2117e-02
# [Epoch 9] Train loss: 3.6033e-02 | Val loss: 2.9356e-02
# [Epoch 10] Train loss: 2.5339e-02 | Val loss: 2.1111e-02
# [Epoch 11] Train loss: 1.8508e-02 | Val loss: 1.6046e-02
# [Epoch 12] Train loss: 1.4593e-02 | Val loss: 1.3338e-02
# [Epoch 13] Train loss: 1.2602e-02 | Val loss: 1.1999e-02
# [Epoch 14] Train loss: 1.1630e-02 | Val loss: 1.1319e-02
# [Epoch 15] Train loss: 1.1107e-02 | Val loss: 1.0905e-02
# [Epoch 16] Train loss: 1.0757e-02 | Val loss: 1.0587e-02
# [Epoch 17] Train loss: 1.0526e-02 | Val loss: 1.0433e-02
# [Epoch 18] Train loss: 1.0371e-02 | Val loss: 1.0274e-02
# [Epoch 19] Train loss: 1.0208e-02 | Val loss: 1.0105e-02
# [Epoch 20] Train loss: 1.0038e-02 | Val loss: 9.9240e-03
# [Epoch 21] Train loss: 9.8495e-03 | Val loss: 9.7273e-03
# [Epoch 22] Train loss: 9.6448e-03 | Val loss: 9.5107e-03
# [Epoch 23] Train loss: 9.4168e-03 | Val loss: 9.2702e-03
# [Epoch 24] Train loss: 9.1639e-03 | Val loss: 9.0018e-03
# [Epoch 25] Train loss: 8.8804e-03 | Val loss: 8.6988e-03
# [Epoch 26] Train loss: 8.5556e-03 | Val loss: 8.3500e-03
# [Epoch 27] Train loss: 8.1777e-03 | Val loss: 7.9402e-03
# [Epoch 28] Train loss: 7.7324e-03 | Val loss: 7.4509e-03
# [Epoch 29] Train loss: 7.1890e-03 | Val loss: 6.8492e-03
# [Epoch 30] Train loss: 6.5188e-03 | Val loss: 6.1005e-03
# [Epoch 31] Train loss: 5.6859e-03 | Val loss: 5.1781e-03
# [Epoch 32] Train loss: 4.6818e-03 | Val loss: 4.1028e-03
# [Epoch 33] Train loss: 3.8522e-03 | Val loss: 3.5496e-03
# [Epoch 34] Train loss: 3.3099e-03 | Val loss: 3.0232e-03
# [Epoch 35] Train loss: 2.7995e-03 | Val loss: 2.5376e-03
# [Epoch 36] Train loss: 2.3360e-03 | Val loss: 2.1038e-03
# [Epoch 37] Train loss: 1.9265e-03 | Val loss: 1.7275e-03
# [Epoch 38] Train loss: 1.5752e-03 | Val loss: 1.4083e-03
# [Epoch 39] Train loss: 1.2795e-03 | Val loss: 1.1430e-03
# [Epoch 40] Train loss: 1.0345e-03 | Val loss: 9.2467e-04
# [Epoch 41] Train loss: 8.3449e-04 | Val loss: 7.4773e-04
# [Epoch 42] Train loss: 6.7311e-04 | Val loss: 6.0631e-04
# [Epoch 43] Train loss: 5.4554e-04 | Val loss: 4.9546e-04
# [Epoch 44] Train loss: 4.4681e-04 | Val loss: 4.1109e-04
# [Epoch 45] Train loss: 3.7203e-04 | Val loss: 3.4723e-04
# [Epoch 46] Train loss: 3.1687e-04 | Val loss: 3.0068e-04
# [Epoch 47] Train loss: 2.7711e-04 | Val loss: 2.6764e-04
# [Epoch 48] Train loss: 2.4889e-04 | Val loss: 2.4391e-04
# [Epoch 49] Train loss: 2.3313e-04 | Val loss: 2.3478e-04
# [Epoch 50] Train loss: 2.2475e-04 | Val loss: 2.2691e-04
# [Epoch 51] Train loss: 2.1755e-04 | Val loss: 2.2008e-04
# [Epoch 52] Train loss: 2.1138e-04 | Val loss: 2.1430e-04
# [Epoch 53] Train loss: 2.0597e-04 | Val loss: 2.0934e-04
# [Epoch 54] Train loss: 2.0147e-04 | Val loss: 2.0499e-04
# [Epoch 55] Train loss: 1.9749e-04 | Val loss: 2.0112e-04
# [Epoch 56] Train loss: 1.9406e-04 | Val loss: 1.9775e-04
# [Epoch 57] Train loss: 1.9103e-04 | Val loss: 1.9478e-04
# [Epoch 58] Train loss: 1.8827e-04 | Val loss: 1.9222e-04
# [Epoch 59] Train loss: 1.8595e-04 | Val loss: 1.8987e-04
# [Epoch 60] Train loss: 1.8382e-04 | Val loss: 1.8776e-04
# [Epoch 61] Train loss: 1.8199e-04 | Val loss: 1.8596e-04
# [Epoch 62] Train loss: 1.8032e-04 | Val loss: 1.8428e-04
# [Epoch 63] Train loss: 1.7887e-04 | Val loss: 1.8292e-04
# [Epoch 64] Train loss: 1.7760e-04 | Val loss: 1.8153e-04
# [Epoch 65] Train loss: 1.7671e-04 | Val loss: 1.8102e-04
# [Epoch 66] Train loss: 1.7624e-04 | Val loss: 1.8054e-04
# [Epoch 67] Train loss: 1.7573e-04 | Val loss: 1.7999e-04
# [Epoch 68] Train loss: 1.7523e-04 | Val loss: 1.7964e-04
# [Epoch 69] Train loss: 1.7485e-04 | Val loss: 1.7912e-04
# [Epoch 70] Train loss: 1.7445e-04 | Val loss: 1.7860e-04
# [Epoch 71] Train loss: 1.7402e-04 | Val loss: 1.7823e-04
# [Epoch 72] Train loss: 1.7370e-04 | Val loss: 1.7813e-04
# [Epoch 73] Train loss: 1.7344e-04 | Val loss: 1.7763e-04
# [Epoch 74] Train loss: 1.7323e-04 | Val loss: 1.7732e-04
# [Epoch 75] Train loss: 1.7291e-04 | Val loss: 1.7701e-04
# [Epoch 76] Train loss: 1.7270e-04 | Val loss: 1.7682e-04
# [Epoch 77] Train loss: 1.7246e-04 | Val loss: 1.7658e-04
# [Epoch 78] Train loss: 1.7234e-04 | Val loss: 1.7636e-04
# [Epoch 79] Train loss: 1.7218e-04 | Val loss: 1.7625e-04
# [Epoch 80] Train loss: 1.7201e-04 | Val loss: 1.7606e-04
# [Epoch 81] Train loss: 1.7200e-04 | Val loss: 1.7602e-04
# [Epoch 82] Train loss: 1.7189e-04 | Val loss: 1.7601e-04
# [Epoch 83] Train loss: 1.7182e-04 | Val loss: 1.7594e-04
# [Epoch 84] Train loss: 1.7180e-04 | Val loss: 1.7587e-04
# [Epoch 85] Train loss: 1.7173e-04 | Val loss: 1.7575e-04
# [Epoch 86] Train loss: 1.7168e-04 | Val loss: 1.7575e-04
# [Epoch 87] Train loss: 1.7167e-04 | Val loss: 1.7565e-04
# [Epoch 88] Train loss: 1.7164e-04 | Val loss: 1.7566e-04
# [Epoch 89] Train loss: 1.7160e-04 | Val loss: 1.7561e-04
# [Epoch 90] Train loss: 1.7158e-04 | Val loss: 1.7554e-04
# [Epoch 91] Train loss: 1.7150e-04 | Val loss: 1.7553e-04
# [Epoch 92] Train loss: 1.7151e-04 | Val loss: 1.7554e-04
# [Epoch 93] Train loss: 1.7147e-04 | Val loss: 1.7543e-04
# [Epoch 94] Train loss: 1.7147e-04 | Val loss: 1.7543e-04
# [Epoch 95] Train loss: 1.7145e-04 | Val loss: 1.7539e-04
# [Epoch 96] Train loss: 1.7143e-04 | Val loss: 1.7534e-04
# [Epoch 97] Train loss: 1.7142e-04 | Val loss: 1.7537e-04
# [Epoch 98] Train loss: 1.7132e-04 | Val loss: 1.7539e-04
# [Epoch 99] Train loss: 1.7142e-04 | Val loss: 1.7533e-04
# [Epoch 100] Train loss: 1.7136e-04 | Val loss: 1.7535e-04
# Final model saved as lorenz96/outputshybrid_network.pth

# %%
Nt = 25

# Load the model, uncomment to load stored weights
# model.load_state_dict(torch.load(
#    f'{PATH}/stored/{model_type}/best_dt{dt}_Nx{Nx}_F{F}_network.pth', weights_only=True))

# Predictions
inference = Inference(model, mean, std, model_type=model_type,
                        device='cuda' if torch.cuda.is_available() else 'cpu')
inference.predict_trajectory(val_set, steps=Nt, Nx=true_model.Nx)

# %% [markdown]
# ### Conclusion
#
# In this practical session, we explored several neural network architectures for modelling the dynamics of chaotic systems.
# The key takeaway is that incorporating domain knowledge—such as the structure of the underlying physical equations or the use of numerical integration schemes—can significantly enhance the performance and robustness of learned surrogate models.
#
# These type of approaches are particularly relevant in the context of data assimilation, where surrogate models that respect physical laws are essential for reliable forecasting. This line of research is actively being pursued in operational weather and climate modelling, and it is expected to play an increasingly important role in the future of Earth system prediction.
